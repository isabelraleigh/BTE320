# %% [markdown]
# <a href="https://colab.research.google.com/github/isabelraleigh/BTE320/blob/main/inClassAssignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales value ($): "))

cogs = .4 * sales
gross_profit = sales - cogs

print(f"Sales: ${sales}")
print(f"COGS: ${cogs:}")
print(f"Gross Profit: ${gross_profit}")
# Out:
# Enter sales value ($): 12000
# Sales: $12000.0
# COGS: $4800.0
# Gross Profit: $7200.0

# %%
sales = float(input("Enter sales value ($): "))
tax_rate = float(input("Enter tax rate (%): "))

cogs = 0.4 * sales
gross_profit = sales - cogs
taxes = gross_profit * tax_rate/100
net_income = gross_profit - taxes

print(f"Sales: ${sales}")
print(f"COGS: ${cogs:}")
print(f"Gross Profit: ${gross_profit}")
print(f"Taxes: ${taxes}")
print(f"Net Profit: ${net_income}")
# Out:
# Enter sales value ($): 12000
# Enter tax rate (%): 3
# Sales: $12000.0
# COGS: $4800.0
# Gross Profit: $7200.0
# Taxes: $216.0
# Net Profit: $6984.0

# %%
num1 = float(input("Enter number: "))
num2 = float(input("Enter number: "))
oper = input("Enter operator (+, -, *, /, etc.): ")

if oper == "+":
  res = num1 + num2
elif oper == "-":
  res = num1 - num2
elif oper == "*":
  res = num1 * num2
elif oper == "/":
  res = num1 / num2
elif oper == "**":
  res = num1 ** num2
elif oper == "//":
  res = num1 // num2
elif oper == "%":
  res = num1 % num2
else:
  print("Invalid operator")
  res = None


print(f"Result: {res}")
# Out:
# Enter number: 3
# Enter number: 2
# Enter operator (+, -, *, /, etc.): **
# Result: 9.0

# %%
print(" Hour Fee")
for hour in range(1,9,1):
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 25:
    fee = 20.0
  print(f" {hour}: " , fee)
# Out:
#  Hour Fee
#  1:  10.0
#  2:  10.0
#  3:  12.5
#  4:  15.0
#  5:  17.5
#  6:  20.0
#  7:  22.5
#  8:  25.0

# %%
import math

ticketprice = 10
defaultAudience = 20

print(" Ad$ Profit")
for adMoney in range(0,201,25):
  revenue =  (defaultAudience + 2 * round( math.sqrt(adMoney))) * ticketprice
  costs = 200 + adMoney
  profit = revenue - costs
  print(f"{float(adMoney)}  {float(profit)}")
# Out:
#  Ad$ Profit
# 0.0  0.0
# 25.0  75.0
# 50.0  90.0
# 75.0  105.0
# 100.0  100.0
# 125.0  95.0
# 150.0  90.0
# 175.0  85.0
# 200.0  80.0

# %%
print(" Hour Fee")
hour = 1
while hour < 9: # or while hour <= 8
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 25:
    fee = 20.0
  hour += 1
  print(f" {hour}: " , fee)
# Out:
#  Hour Fee
#  2:  10.0
#  3:  10.0
#  4:  12.5
#  5:  15.0
#  6:  17.5
#  7:  20.0
#  8:  22.5
#  9:  25.0

# %%
import math

ticketprice = 10
defaultAudience = 20
adMoney = 0
print(" Ad$ Profit")
while adMoney < 201:
  revenue =  (defaultAudience + 2 * round( math.sqrt(adMoney))) * ticketprice
  costs = 200 + adMoney
  profit = revenue - costs
  print(f"{float(adMoney)}  {float(profit)}")
  adMoney += 25
# Out:
#  Ad$ Profit
# 0.0  0.0
# 25.0  75.0
# 50.0  90.0
# 75.0  105.0
# 100.0  100.0
# 125.0  95.0
# 150.0  90.0
# 175.0  85.0
# 200.0  80.0
